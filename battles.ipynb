# %% [markdown]
# <a href="https://colab.research.google.com/github/komalk98/battle/blob/main/battles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
battle = pd.read_csv('/content/sample_data/battles.csv')

# %%
battle.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
battle.shape
# Out:
# (38, 25)

# %%
battle.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
battle.rename(columns={'attacker_1':'primary_attacker'},inplace=True)
battle.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
battle.rename(columns={'defender_1':'primary_defender'},inplace=True)
battle.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
battle['attacker_king'].value_counts()
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
battle['location'].value_counts()
# Out:
# Riverrun                                3
# Winterfell                              3
# Storm's End                             2
# Harrenhal                               2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Torrhen's Square                        2
# Golden Tooth                            1
# Seagard                                 1
# Castle Black                            1
# Shield Islands                          1
# Saltpans                                1
# Ruby Ford                               1
# Ryamsport, Vinetown, Starfish Harbor    1
# Dragonstone                             1
# The Twins                               1
# Red Fork                                1
# Duskendale                              1
# King's Landing                          1
# Crag                                    1
# Mummer's Ford                           1
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
from matplotlib import rc
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(data=battle, x='attacker_king', y='attacker_size')
plt.show()

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(data=battle, x='defender_king',y='defender_size')
plt.show()

# %%
sns.countplot(data=battle, x='attacker_king', hue='battle_type')
plt.show()

# %% [markdown]
# ## ***the following code is related to death dataset ***:

# %%
death = pd.read_csv('/content/sample_data/character-deaths.csv')
death.head()
# Out:
#                       Name      Allegiances  Death Year  ...  SoS  FfC  DwD
# 0           Addam Marbrand        Lannister         NaN  ...    1    1    0
# 1  Aegon Frey (Jinglebell)             None       299.0  ...    1    0    0
# 2          Aegon Targaryen  House Targaryen         NaN  ...    0    0    1
# 3            Adrack Humble    House Greyjoy       300.0  ...    0    0    1
# 4           Aemon Costayne        Lannister         NaN  ...    1    0    0
#
# [5 rows x 13 columns]

# %%
death.shape
# Out:
# (917, 13)

# %%
death.columns
# Out:
# Index(['Name', 'Allegiances', 'Death Year', 'Book of Death', 'Death Chapter',
#        'Book Intro Chapter', 'Gender', 'Nobility', 'GoT', 'CoK', 'SoS', 'FfC',
#        'DwD'],
#       dtype='object')

# %%
death.Gender.value_counts().reset_index()
# Out:
#    index  Gender
# 0      1     760
# 1      0     157

# %%
death.Name.value_counts()
# Out:
# Myles              2
# Addam Marbrand     1
# Othell Yarwyck     1
# Olyvar Frey        1
# Ondrew Locke       1
#                   ..
# Grunt              1
# Gueren             1
# Guncer Sunglass    1
# Guyard Morrigen    1
# Talbert Serry      1
# Name: Name, Length: 916, dtype: int64

# %%
sns.set(rc={'figure.figsize':(17,10)})
sns.countplot(death['Death Year'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(30,10)})
sns.countplot(data=death,x='Allegiances')
plt.show()

# %%
death.columns.shape
# Out:
# (13,)

# %%
death.isnull().any()
# Out:
# Name                  False
# Allegiances           False
# Death Year             True
# Book of Death          True
# Death Chapter          True
# Book Intro Chapter     True
# Gender                False
# Nobility              False
# GoT                   False
# CoK                   False
# SoS                   False
# FfC                   False
# DwD                   False
# dtype: bool

# %%
r = death[(death['Allegiances'] == 'Lannister') & (death['Gender'] == 0)]
r
# Out:
#                    Name Allegiances  Death Year  ...  SoS  FfC  DwD
# 133              Chella   Lannister         NaN  ...    1    0    0
# 248   Falyse Stokeworth   Lannister       300.0  ...    0    1    0
# 274     Genna Lannister   Lannister         NaN  ...    0    1    0
# 377     Jacelyn Bywater   Lannister       299.0  ...    0    0    0
# 402       Jocelyn Swyft   Lannister         NaN  ...    0    1    1
# 472   Lollys Stokeworth   Lannister         NaN  ...    1    0    0
# 584  Myrcella Baratheon   Lannister         NaN  ...    0    1    0
# 753                Shae   Lannister       300.0  ...    1    0    0
# 781       Sybell Spicer   Lannister         NaN  ...    1    1    0
# 789        Taena of Myr   Lannister         NaN  ...    1    1    0
# 792    Tanda Stokeworth   Lannister       300.0  ...    1    0    0
# 811           Tion Frey   Lannister       299.0  ...    1    0    0
#
# [12 rows x 13 columns]
